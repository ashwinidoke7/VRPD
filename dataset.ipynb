# %%
import numpy as np

# %%
# 10 cities
city_list = np.array([
    [2, 5],      # City 0
    [7, 7],      # City 1
    [6, 3],      # City 2
    [7, 4],      # City 3
    [4, 3],      # City 4
    [5, 6],      # City 5
    [6, 5],      # City 6
    [3, 2],      # City 7
    [1.7, 1.7],  # City 9
])

# %%
# 20 cities
city_list = np.array([
    [3, 9],      # City 0
    [7, 7],      # City 1
    [8, 2],      # City 2
    [7, 4],      # City 3
    [4, 3],      # City 4
    [2, 7],      # City 5
    [4, 8],      # City 6
    [5, 6],      # City 7
    [6, 8],      # City 8
    [8.6, 9],    # City 9
    [5, 9],      # City 10
    [6, 5],      # City 11
    [2, 5],      # City 12
    [3, 8],      # City 13
    [1.7, 1.7],  # City 14
    [9, 2],      # City 15
    [9, 4],      # City 16
    [3, 2],      # City 17
    [6, 10],     # City 18
    [6, 3],      # City 19
])

# %%
# 50 cities
city_list = np.array([
    [3, 9],       # City 0
    [7, 7],       # City 1
    [14, 6],      # City 2
    [7, 4],       # City 3
    [4, 3],       # City 4
    [2, 7],       # City 5
    [2, 15],      # City 6
    [2.7, 11.5],  # City 7
    [9, 11],      # City 8
    [12, 14],     # City 9
    [5, 9],       # City 10
    [6, 5],       # City 11
    [11, 2],      # City 12
    [14, 12],     # City 13
    [5, 13],      # City 14
    [10, 5],      # City 15
    [11, 8],      # City 16
    [3, 2],       # City 17
    [6, 10],      # City 18
    [6, 3],       # City 19
    [11, 5],      # City 20
    [3, 8],       # City 21
    [8.6, 9],     # City 22
    [13, 3],      # City 23
    [13, 10],     # City 24
    [1.7, 1.7],   # City 25
    [4, 4],       # City 26
    [4, 14],      # City 27
    [12, 6],      # City 28
    [6, 8],       # City 29
    [9, 2],       # City 30
    [13, 1],      # City 31
    [4.4, 12],    # City 32
    [10.5, 11.5], # City 33
    [2, 5],       # City 34
    [7.95, 13],   # City 35
    [8, 14],      # City 36
    [14, 5],      # City 37
    [3, 5],       # City 38
    [2, 8.5],     # City 39
    [5, 6],       # City 40
    [11, 13],     # City 41
    [12, 10],     # City 42
    [8, 2],       # City 43
    [4, 11],      # City 44
    [9, 4],       # City 45
    [4, 8],       # City 46
    [2, 10.5],    # City 47
    [12, 3],      # City 48
    [10, 4]       # City 49
])

# %%
# 100 cities
city_list = np.array([
    [3, 9],       # City 0
    [7, 7],       # City 1
    [14, 6],      # City 2
    [7, 4],       # City 3
    [4, 3],       # City 4
    [2, 7],       # City 5
    [2, 15],      # City 6
    [2.7, 11.5],  # City 7
    [9, 11],      # City 8
    [12, 14],     # City 9
    [5, 9],       # City 10
    [6, 5],       # City 11
    [11, 2],      # City 12
    [14, 12],     # City 13
    [5, 13],      # City 14
    [10, 5],      # City 15
    [11, 8],      # City 16
    [3, 2],       # City 17
    [6, 10],      # City 18
    [6, 3],       # City 19
    [11, 5],      # City 20
    [3, 8],       # City 21
    [8.6, 9],     # City 22
    [13, 3],      # City 23
    [13, 10],     # City 24
    [1.7, 1.7],   # City 25
    [4, 4],       # City 26
    [4, 14],      # City 27
    [12, 6],      # City 28
    [6, 8],       # City 29
    [9, 2],       # City 30
    [13, 1],      # City 31
    [4.4, 12],    # City 32
    [10.5, 11.5], # City 33
    [2, 5],       # City 34
    [7.95, 13],      # City 35
    [8, 14],      # City 36
    [14, 5],      # City 37
    [3, 5],       # City 38
    [2, 8.5],     # City 39
    [5, 6],       # City 40
    [11, 13],     # City 41
    [12, 10],     # City 42
    [8, 2],       # City 43
    [4, 11],      # City 44
    [9, 4],       # City 45
    [4, 8],       # City 46
    [2, 10.5],    # City 47
    [12, 3],      # City 48
    [10, 4],      # City 49
     [5, 11],     # City 50
    [6, 2],       # City 51
    [8, 9],       # City 52
    [14, 11],     # City 53
    [2, 13],      # City 54
    [11, 7],      # City 55
    [9, 7],       # City 56
    [3, 7],       # City 57
    [11.5, 11.5],   # City 58
    [8, 12],        # City 59
    [7.6, 7.3],     # City 60
    [4.6, 6.1],     # City 61
    [14.2, 3.1],    # City 62
    [1.6, 9.1],     # City 63
    [9.6, 9.1],     # City 64
    [12.6, 4.6],    # City 65
    [10.6, 14.2],   # City 66
    [3.1, 3.1],     # City 67
    [8.4, 4.6],     # City 68
    [6.1, 6.1],     # City 69
    [13.4, 7.6],    # City 70
    [5.4, 1.6],     # City 71
    [3.1, 9.9],     # City 72
    [1.6, 3.1],     # City 73
    [12.1, 7.6],    # City 74
    [9.1, 15],      # City 75
    [10.9, 10.6],   # City 76
    [7.6, 12.7],    # City 77
    [4.6, 4.6],     # City 78
    [14.6, 13.6],   # City 79
    [4.2, 10.6],    # City 80
    [2.8, 12.1],    # City 81
    [12.1, 12.1],   # City 82
    [9.1, 10.6],    # City 83
    [11.3, 9],      # City 84
    [7.6, 4.6],     # City 85
    [3.1, 10.6],    # City 86
    [6.2, 15],      # City 87
    [14.1, 10.6],   # City 88
    [13.2, 14.5],   # City 89
    [12, 7.1],      # City 90
    [10.8, 2.3],    # City 91
    [13.5, 9.3],    # City 92
    [9.4, 2.4],     # City 93
    [14.8, 5.9],    # City 94
    [8.3, 13.2],    # City 95
    [11, 5.3],      # City 96
    [3.3, 14.2],    # City 97
    [5.8, 13],      # City 98
    [12.7, 10.9]    # City 99
])

# %%
# 200 cities
city_list = np.array([
    [3, 9],       # City 0
    [7, 7],       # City 1
    [14, 6],      # City 2
    [7, 4],       # City 3
    [4, 3],       # City 4
    [2, 7],       # City 5
    [2, 15],      # City 6
    [2.7, 11.5],  # City 7
    [9, 11],      # City 8
    [12, 14],     # City 9
    [5, 9],       # City 10
    [6, 5],       # City 11
    [11, 2],      # City 12
    [14, 12],     # City 13
    [5, 13],      # City 14
    [10, 5],      # City 15
    [11, 8],      # City 16
    [3, 2],       # City 17
    [6, 10],      # City 18
    [6, 3],       # City 19
    [11, 5],      # City 20
    [3, 8],       # City 21
    [8.6, 9],     # City 22
    [13, 3],      # City 23
    [13, 10],     # City 24
    [1.7, 1.7],   # City 25
    [4, 4],       # City 26
    [4.4, 14.4],      # City 27
    [16, 6],      # City 28
    [6, 8],       # City 29
    [9, 2],       # City 30
    [13, 1],      # City 31
    [4.4, 12],    # City 32
    [10.5, 11.5], # City 33
    [4.5, 5],       # City 34
    [9, 13],      # City 35
    [8, 14],      # City 36
    [16.6, 5],      # City 37
    [3, 5],       # City 38
    [2, 8.5],     # City 39
    [5, 6],       # City 40
    [3.2, 18],     # City 41
    [12, 10],     # City 42
    [8, 2],       # City 43
    [4, 11],      # City 44
    [9, 4],       # City 45
    [4, 8],       # City 46
    [2, 10.5],    # City 47
    [12, 3],      # City 48
    [10, 4],      # City 49
     [5, 11],     # City 50
    [6, 2],       # City 51
    [8, 9],       # City 52
    [14, 11],     # City 53
    [2, 13],      # City 54
    [11, 7],      # City 55
    [9, 7],       # City 56
    [3, 7],       # City 57
    [11.5, 11.5],   # City 58
    [8, 12],        # City 59
    [7.6, 7.3],     # City 60
    [4.6, 6.1],     # City 61
    [14.2, 3.1],    # City 62
    [1.6, 9.1],     # City 63
    [9.6, 9.1],     # City 64
    [19.6, 4.6],    # City 65
    [18.6, 14.2],   # City 66
    [3.1, 3.1],     # City 67
    [8.4, 4.6],     # City 68
    [6.1, 6.1],     # City 69
    [13.4, 7.6],    # City 70
    [5.4, 1.6],     # City 71
    [3.1, 9.9],     # City 72
    [1.6, 3.1],     # City 73
    [14.1, 7.6],    # City 74
    [9.1, 15],      # City 75
    [10.9, 10.6],   # City 76
    [17.6, 12.7],    # City 77
    [4.6, 4.6],     # City 78
    [14.6, 13.6],   # City 79
    [4.2, 10.6],    # City 80
    [2.8, 12.1],    # City 81
    [12.1, 12.1],   # City 82
    [9.1, 10.6],    # City 83
    [11.3, 9],      # City 84
    [7.6, 4.6],     # City 85
    [3.1, 10.6],    # City 86
    [6.2, 15],      # City 87
    [14.1, 10.6],   # City 88
    [13.2, 14.5],   # City 89
    [17, 8.1],      # City 90
    [10.8, 18.2],    # City 91
    [13.5, 9.3],    # City 92
    [9.4, 0.4],     # City 93
    [14.8, 5.9],    # City 94
    [8.3, 13.2],    # City 95
    [12, 5.3],      # City 96
    [3.3, 14.2],    # City 97
    [5.8, 13],      # City 98
    [12.7, 10.9],   # City 99
    [15.2, 15.5],   # City 100
    [17.5, 10.5],    # City 101
    [18.3, 10.4],    # City 102
    [19.1, 13.3],    # City 103
    [9.9, 14.2],    # City 104
    [18.7, 18.1],   # City 105
    [11.5, 16.8],     # City 106
    [12.3, 17.9],    # City 107
    [13.1, 18.8],    # City 108
    [13.9, 17.7],    # City 109
    [14.7, 16.6],    # City 110
    [15.5, 18.5],   # City 111
    [16.2, 17.4],   # City 112
    [17, 16.3],     # City 113
    [17.8, 15.2],   # City 114
    [16.6, 4.1],   # City 115
    [4.4, 18.4],     # City 116
    [15.3, 19.9],   # City 117
    [12.1, 18.8],   # City 118
    [12.5, 4.5],     # City 119
    [11.2, 6.3],     # City 120
    [10, 8.1],       # City 121
    [8.8, 9.9],      # City 122
    [17.6, 11.7],     # City 123
    [6.4, 13.5],     # City 124
    [5.2, 15.3],     # City 125
    [4, 17.1],       # City 126
    [7, 18.9],       # City 127
    [9, 16.7],       # City 128
    [11, 14.5],      # City 129
    [13, 12.3],      # City 130
    [15, 10.1],      # City 131
    [17, 17.9],       # City 132
    [18, 15.7],       # City 133
    [19, 14.5],       # City 134
    [18.9, 1.3],       # City 135
    [18, 4.1],        # City 136
    [17.7, 6.9],        # City 137
    [17.9, 13.7],        # City 138
    [18.5, 8.5],      # City 139
    [18, 5.3],       # City 140
    [19, 4.1],       # City 141
    [10.4, 18.9],       # City 142
    [12, 13.7],      # City 143
    [18, 1.5],      # City 144
    [18.6, 19.3],       # City 145
    [17, 7.1],       # City 146
    [19, 4.9],       # City 147
    [17.7, 2.7],       # City 148
    [14.5, 1.5],       # City 149
    [12, 7.3],       # City 150
    [10, 9.1],       # City 151
    [8, 10.9],       # City 152
    [6, 12.7],       # City 153
    [4, 14.5],       # City 154
    [2, 16.3],       # City 155
    [5, 18.1],       # City 156
    [7, 19.9],       # City 157
    [9, 17.7],       # City 158
    [11, 15.5],      # City 159
    [13, 13.3],      # City 160
    [17, 11.1],      # City 161
    [17, 18.9],       # City 162
    [14, 16.7],       # City 163
    [11.7, 4.2],       # City 164
    [10, 2.3],       # City 165
    [8, 5.1],        # City 166
    [1.5, 11.5],      # City 167
    [2.5, 11.5],      # City 168
    [1.5, 12.5],      # City 169
    [3.5, 11.5],      # City 170
    [0.7, 3.5],      # City 171
    [2.5, 13.5],      # City 172
    [3.5, 2.5],      # City 173
    [4.5, 1.5],      # City 174
    [1.5, 4.5],      # City 175
    [2.5, 3.7],      # City 176
    [14, 14.9],       # City 177
    [16, 13.7],       # City 178
    [14, 2],         # City 179
    [18.5, 11.3],       # City 180
    [6, 12.1],       # City 181
    [4, 13.9],       # City 182
    [2, 4.7],       # City 183
    [5, 17.5],       # City 184
    [7, 19.3],       # City 185
    [11, 17.1],       # City 186
    [11, 14.9],      # City 187
    [13.5, 12.7],      # City 188
    [15, 10.5],      # City 189
    [7.5, 5.6],     # City 190
    [8.2, 14.5],     # City 191
    [19, 3.4],       # City 192
    [9.8, 19.3],     # City 193
    [10.6, 1.2],    # City 194
    [11.4, 0.1],    # City 195
    [12.2, 2],      # City 196
    [13, 13.9],      # City 197
    [13.8, 4.8],    # City 198
    [16.6, 2.2],    # City 199
])
